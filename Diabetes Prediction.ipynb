# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("C:\\Users\\abdul\\Desktop\\Jupyter\\Datasets\\Healthcare-Diabetes.csv")

# %%
df.head()
# Out:
#    Id  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0   1            6      148             72             35        0  33.6
# 1   2            1       85             66             29        0  26.6
# 2   3            8      183             64              0        0  23.3
# 3   4            1       89             66             23       94  28.1
# 4   5            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2768 entries, 0 to 2767
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Id                        2768 non-null   int64
#  1   Pregnancies               2768 non-null   int64
#  2   Glucose                   2768 non-null   int64
#  3   BloodPressure             2768 non-null   int64
#  4   SkinThickness             2768 non-null   int64
#  5   Insulin                   2768 non-null   int64
#  6   BMI                       2768 non-null   float64
#  7   DiabetesPedigreeFunction  2768 non-null   float64
#  8   Age                       2768 non-null   int64
#  9   Outcome                   2768 non-null   int64
# dtypes: float64(2), int64(8)
# memory usage: 216.4 KB

# %%
df.isnull().sum()
# Out:
# Id                          0
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
(df==0).sum()
# Out:
# Id                             0
# Pregnancies                  412
# Glucose                       18
# BloodPressure                125
# SkinThickness                800
# Insulin                     1330
# BMI                           39
# DiabetesPedigreeFunction       0
# Age                            0
# Outcome                     1816
# dtype: int64

# %%
(df.loc[:, df.columns != 'Outcome'] == 0).sum().sum()  #Total missing values
# Out:
# 2724

# %%
df.hist(figsize=(10, 15), bins=15)
plt.show()

# %%
df.columns
# Out:
# Index(['Id', 'Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness',
#        'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
column_to_replace = ['Pregnancies','Glucose', 'BloodPressure','SkinThickness','Insulin','BMI']

# %%
df[column_to_replace] = df[column_to_replace].replace(0,np.nan)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2768 entries, 0 to 2767
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Id                        2768 non-null   int64
#  1   Pregnancies               2356 non-null   float64
#  2   Glucose                   2750 non-null   float64
#  3   BloodPressure             2643 non-null   float64
#  4   SkinThickness             1968 non-null   float64
#  5   Insulin                   1438 non-null   float64
#  6   BMI                       2729 non-null   float64
#  7   DiabetesPedigreeFunction  2768 non-null   float64
#  8   Age                       2768 non-null   int64
#  9   Outcome                   2768 non-null   int64
# dtypes: float64(7), int64(3)
# memory usage: 216.4 KB

# %%
df.isnull().sum()
# Out:
# Id                             0
# Pregnancies                  412
# Glucose                       18
# BloodPressure                125
# SkinThickness                800
# Insulin                     1330
# BMI                           39
# DiabetesPedigreeFunction       0
# Age                            0
# Outcome                        0
# dtype: int64

# %%
df.hist(figsize=(10, 15), bins=15)
plt.show()

# %%
df.drop_duplicates()
# Out:
#         Id  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0        1          6.0    148.0           72.0           35.0      NaN  33.6
# 1        2          1.0     85.0           66.0           29.0      NaN  26.6
# 2        3          8.0    183.0           64.0            NaN      NaN  23.3
# 3        4          1.0     89.0           66.0           23.0     94.0  28.1
# 4        5          NaN    137.0           40.0           35.0    168.0  43.1
# ...    ...          ...      ...            ...            ...      ...   ...
# 2763  2764          2.0     75.0           64.0           24.0     55.0  29.7
# 2764  2765          8.0    179.0           72.0           42.0    130.0  32.7
# 2765  2766          6.0     85.0           78.0            NaN      NaN  31.2
# 2766  2767          NaN    129.0          110.0           46.0    130.0  67.1
# 2767  2768          2.0     81.0           72.0           15.0     76.0  30.1
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2768 entries, 0 to 2767
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Id                        2768 non-null   int64
#  1   Pregnancies               2356 non-null   float64
#  2   Glucose                   2750 non-null   float64
#  3   BloodPressure             2643 non-null   float64
#  4   SkinThickness             1968 non-null   float64
#  5   Insulin                   1438 non-null   float64
#  6   BMI                       2729 non-null   float64
#  7   DiabetesPedigreeFunction  2768 non-null   float64
#  8   Age                       2768 non-null   int64
#  9   Outcome                   2768 non-null   int64
# dtypes: float64(7), int64(3)
# memory usage: 216.4 KB

# %%
sns.scatterplot(data=df,x='Age',y='Glucose',hue='Outcome')
# Out:
# <Axes: xlabel='Age', ylabel='Glucose'>

# %%
sns.scatterplot(data=df,x='Age',y='BloodPressure',hue='Outcome')
# Out:
# <Axes: xlabel='Age', ylabel='BloodPressure'>

# %%
sns.scatterplot(data=df,x='Age',y='Insulin',hue='Outcome')
# Out:
# <Axes: xlabel='Age', ylabel='Insulin'>

# %%
sns.scatterplot(data=df,x='Age',y='BMI',hue='Outcome')
# Out:
# <Axes: xlabel='Age', ylabel='BMI'>

# %%
ind_drop = df[(df['Insulin']>500) & (df['BMI']>50)].index

# %%
df = df.drop(ind_drop,axis=0)

# %%
df = df.drop('Id',axis=1)

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0          6.0    148.0           72.0           35.0      NaN  33.6
# 1          1.0     85.0           66.0           29.0      NaN  26.6
# 2          8.0    183.0           64.0            NaN      NaN  23.3
# 3          1.0     89.0           66.0           23.0     94.0  28.1
# 4          NaN    137.0           40.0           35.0    168.0  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
sns.countplot(data=df,x='Outcome')
# Out:
# <Axes: xlabel='Outcome', ylabel='count'>

# %%
plt.figure(figsize=(16,8),dpi=200)
sns.heatmap(data=df.corr(),annot=True)
# Out:
# <Axes: >

# %%
X = df.drop('Outcome',axis=1)

# %%
y = df['Outcome']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
from sklearn.impute import KNNImputer
imputer = KNNImputer(missing_values=np.nan, n_neighbors=5, add_indicator=True)
imputer = imputer.fit(X_train)
X_train = imputer.transform(X_train)
X_test = imputer.transform(X_test)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled_X_train = scaler.fit_transform(X_train)
scaled_X_test = scaler.transform(X_test)

# %%
from  sklearn.linear_model import LogisticRegression
log_model = LogisticRegression(solver='liblinear')
log_model.fit(scaled_X_train,y_train)
# Out:
# LogisticRegression(solver='liblinear')

# %%
y_pred = log_model.predict(scaled_X_test)

# %%
from sklearn.metrics import classification_report, ConfusionMatrixDisplay, accuracy_score,confusion_matrix

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.88      0.85       567
#            1       0.70      0.59      0.64       263
#
#     accuracy                           0.79       830
#    macro avg       0.76      0.73      0.74       830
# weighted avg       0.78      0.79      0.78       830

# %%
cm = confusion_matrix(y_test,y_pred)
disp = ConfusionMatrixDisplay(cm)
disp.plot()

# %%
ac = accuracy_score(y_test,y_pred)
print(ac*100)
# Out:
# 78.79518072289157

# %%
from sklearn.neighbors import KNeighborsClassifier
knn_model = KNeighborsClassifier()
knn_model.fit(scaled_X_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = knn_model.predict(scaled_X_test)

# %%
def reports(y_test,y_pred):
    from sklearn.metrics import classification_report, ConfusionMatrixDisplay, accuracy_score
    print('Classification Report:')
    print(classification_report(y_test,y_pred))
    print('\n')
    print('Accurecy: ')
    ac = accuracy_score(y_test,y_pred)
    print(ac*100)
    print('\n')
    print('Confusion Matrix:')
    cm = confusion_matrix(y_test,y_pred)
    disp = ConfusionMatrixDisplay(cm)
    disp.plot()

# %%
reports(y_test,y_pred)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.87      0.86      0.86       567
#            1       0.70      0.71      0.71       263
#
#     accuracy                           0.81       830
#    macro avg       0.78      0.79      0.79       830
# weighted avg       0.81      0.81      0.81       830
#
#
#
# Accurecy:
# 81.32530120481928
#
#
# Confusion Matrix:

# %%
from sklearn.svm import SVC
svc = SVC()
svc.fit(scaled_X_train,y_train)
y_pred = svc.predict(scaled_X_test)

# %%
reports(y_test,y_pred)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.86      0.89      0.88       567
#            1       0.75      0.68      0.71       263
#
#     accuracy                           0.83       830
#    macro avg       0.80      0.79      0.79       830
# weighted avg       0.82      0.83      0.82       830
#
#
#
# Accurecy:
# 82.65060240963855
#
#
# Confusion Matrix:

# %%
from sklearn.tree import DecisionTreeClassifier
tree = DecisionTreeClassifier()
tree.fit(scaled_X_train,y_train)
y_pred = tree.predict(scaled_X_test)

# %%
reports(y_test,y_pred)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99       567
#            1       0.96      0.98      0.97       263
#
#     accuracy                           0.98       830
#    macro avg       0.97      0.98      0.98       830
# weighted avg       0.98      0.98      0.98       830
#
#
#
# Accurecy:
# 98.0722891566265
#
#
# Confusion Matrix:

# %%
from sklearn.ensemble import RandomForestClassifier
RF = RandomForestClassifier()
RF.fit(X_train,y_train)
y_pred = RF.predict(X_test)

# %%
reports(y_test,y_pred)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99       567
#            1       0.97      0.97      0.97       263
#
#     accuracy                           0.98       830
#    macro avg       0.98      0.98      0.98       830
# weighted avg       0.98      0.98      0.98       830
#
#
#
# Accurecy:
# 98.0722891566265
#
#
# Confusion Matrix:

# %%
df = pd.DataFrame(data=
{'Algorithms':['LogisticRegression','KNN', 'SVM', 'DecisionTreeClassifier','Random Forest'],
'Accuracy %':[78.79,81.32,82.65,98.07,98.07]})
plt.figure(figsize=(14,6))

p = sns.barplot(x='Algorithms', y='Accuracy %',data=df, palette='plasma')
p.set_ylim(70, 100)

for i in p.containers:
    labels = [f'{v.get_height():0.02f}%' for v in i]
    p.bar_label(i, labels=labels)
